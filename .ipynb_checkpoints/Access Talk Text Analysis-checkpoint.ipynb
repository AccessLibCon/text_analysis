# %% [markdown]
# # Access Text Analysis

# %%
import os
import string
import json
import nltk
import glob
import pandas as pd
import matplotlib.pyplot as plt


from shutil import unpack_archive

from nltk.corpus import stopwords
from nltk.classify import SklearnClassifier
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
# Load CSV Files

df_list = []

for f in os.listdir(os.curdir):
    if f.endswith('.csv'):
        print(f)
        df = pd.read_csv(f)
        df_list.append(df)
# Out:
# 2008.csv
# 2009.csv
# 2019.csv
# 2018.csv
# 2001.csv
# 2015.csv
# 2014.csv
# 2000.csv
# 2016.csv
# 2002.csv
# 2003.csv
# 2017.csv
# 2013.csv
# 2007.csv
# 2006.csv
# 2012.csv
# 2004.csv
# 2010.csv
# 2011.csv
# 2005.csv
# 1999.csv
# 1998.csv

# %%
df_list[1]
# Out:
#     year        date         time  \
# 0   2009  2009-10-01    8:30-9:30
# 1   2009  2009-10-01   9:30-10:15
# 2   2009  2009-10-01  10:45-11:05
# 3   2009  2009-10-01  11:05-11:30
# 4   2009  2009-10-01    1:00-1:45
# 5   2009  2009-10-01    1:45-2:30
# 6   2009  2009-10-01    2:30-3:15
# 7   2009  2009-10-01    3:45-4:07
# 8   2009  2009-10-01    4:08-4:30
# 9   2009  2009-10-02    8:30-9:15
# 10  2009  2009-10-02   9:15-10:00
# 11  2009  2009-10-02    1:00-1:45
# 12  2009  2009-10-02    1:45-2:30
# 13  2009  2009-10-02    2:30-2:52
# 14  2009  2009-10-02    2:53-3:15
# 15  2009  2009-10-02    3:45-4:30
# 16  2009  2009-10-03    8:30-9:15
# 17  2009  2009-10-03   9:15-10:30
# 18  2009  2009-10-03  11:00-12:00
# 19  2009  2009-10-03   12:00-1:00
#
#                                              speakers  \
# 0                         Cory Doctorow (Boing Boing)
# 1   Richard Akerman (National Research Council, Ot...
# 2   Mark Jordan (Simon Fraser University, Burnaby,...
# 3   Brian Owen (Simon Fraser University, Burnaby, BC)
# 4   Dan Chudnov (Library of Congress, Washington, DC)
# 5   Donald Moses (UPEI, Charlottetown, PEI), Paul ...
# 6                      Stevan Harnad (UQAM, Montreal)
# 7                                  Roy Tennant (OCLC)
# 8                    Mike Rylander (Equinox Software)
# 9                    Peter Rukavina (Reinvented Inc.)
# 10                      Cary Gordon (Cherry Hill Co.)
# 11  Dorothea Salo (University of Wisconsin, Madiso...
# 12                                 Roy Tennant (OCLC)
# 13  Bess Sadler (University of Virginia, Charlotte...
# 14      Jon Jiras (Rochester Institute of Technology)
# 15  Andrew Nagy (Serials Solutions), Heather Tones...
# 16            Mark Leggott (UPEI, Charlottetown, PEI)
# 17  Cathy Hartman (University of North Texas Libra...
# 18  Gwendolyn MacNairn (Dalhousie Library, Halifax...
# 19  William J. Turkel (University of Western Ontar...
#
#                                                 title  \
# 0   Copyright vs Universal Access to All Human Kno...
# 1                          Will We Command Our Data?
# 2                     COPPUL's LOCKSS Private Network
# 3   Software Lifecycles & Sustainability: a PKP an...
# 4                                   Chudnovian Stuff
# 5   IslandLives: A Flexible Digital Repository Fra...
# 6   Grasping What is Already Within Immediate Reac...
# 7                        ILS in the Sky with Diamonds
# 8                                             OS ILS
# 9                       Applications vs. Capabilities
# 10                                Drupal in Libraries
# 11          Representing and Managing the Data Deluge
# 12  Inspecting the Elephant: Characterizing the Ha...
# 13   Exposing your Hidden Collections with Blacklight
# 14                          eXtensible Catalog Update
# 15  Mobile Apps: Usask iPhone Application / Mobile...
# 16       Virtual Research Environment - 2 Years Later
# 17                        The Portal to Texas History
# 18                        Zotero: A Better Way to Go?
# 19                        Hacking as a Way of Knowing
#
#                                              abstract           type  tags  \
# 0   The Internet promises the realization of two o...        keynote   NaN
# 1   This presentation provides an overview of rece...  talk, binkley   NaN
# 2   COPPUL (the Council of Prairie and Pacific Uni...           talk   NaN
# 3   The PKP and reSearcher open source software su...           talk   NaN
# 4   The Repository Development Group at the Librar...           talk   NaN
# 5   In 2008 the Robertson Library received a priva...           talk   NaN
# 6   Open Access (OA) means free online access to p...           talk   NaN
# 7   Cloud computing has become all the rage, but w...           talk   NaN
# 8                                                 NaN           talk   NaN
# 9   (Originally titled Infinite Malleability: Port...           talk   NaN
# 10  Cary will do an overview of Drupal in Librarie...           talk   NaN
# 11  Grab a bucket, it's raining data! Library data...           talk   NaN
# 12  The Hathi Trust is a collaborative digital rep...           talk   NaN
# 13  More than an OPAC Blacklight is a vibrant and ...           talk   NaN
# 14  eXtensible Catalog software provides next gene...           talk   NaN
# 15  Whether it is eating, studying, flirting, or s...           talk   NaN
# 16   At the 2007 Access Conference I presented on ...           talk   NaN
# 17  The Portal to Texas History is a multi-institu...           talk   NaN
# 18  Academic libraries continue to expand their co...           talk   NaN
# 19  Researchers are familiar with the idea of digi...        keynote   NaN
#
#     slides  video  audio
# 0      NaN    NaN    NaN
# 1      NaN    NaN    NaN
# 2      NaN    NaN    NaN
# 3      NaN    NaN    NaN
# 4      NaN    NaN    NaN
# 5      NaN    NaN    NaN
# 6      NaN    NaN    NaN
# 7      NaN    NaN    NaN
# 8      NaN    NaN    NaN
# 9      NaN    NaN    NaN
# 10     NaN    NaN    NaN
# 11     NaN    NaN    NaN
# 12     NaN    NaN    NaN
# 13     NaN    NaN    NaN
# 14     NaN    NaN    NaN
# 15     NaN    NaN    NaN
# 16     NaN    NaN    NaN
# 17     NaN    NaN    NaN
# 18     NaN    NaN    NaN
# 19     NaN    NaN    NaN

# %%
for df in df_list:
    print(df.abstract)

# %%
#Binary Sentiment

sid = SentimentIntensityAnalyzer()
summary = {"positive":0,"neutral":0,"negative":0}

for df in df_list:
    for x in df.abstract:
        if type(x) != 
        
        ss = sid.polarity_scores(x)
        if ss["compound"] == 0.0:
            analysis = analysis.append({"Sent": "NEU", "Text": x},ignore_index=True)
            summary["neutral"] +=1
        elif ss["compound"] > 0.0:
            analysis = analysis.append({"Sent": "POS", "Text": x},ignore_index=True)
            summary["positive"] +=1
        else:
            analysis = analysis.append({"Sent": "NEG", "Text": x},ignore_index=True)
            summary["negative"] +=1

        
print(summary)
print("Done!")
# Out:
#   File "<ipython-input-23-8bca55a2a2ea>", line 8
#     if type(x) !=
#                   ^
# SyntaxError: invalid syntax
